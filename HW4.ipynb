# %% [markdown]
# <a href="https://colab.research.google.com/github/howard1028/Deep_Visualization/blob/main/HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Network for CIFAR10 Classification
# In this assignment, we will implement a two-layer fully-connected neural network for CIFAR10 classification.

# %% [markdown]
# ## Data Preparation and Visualization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/深度視覺/HW4-20230405T032631Z-001/HW4')

# %%
# You may change `MODEL_DIR` to a existing local directory if you are not using Colab
MODEL_DIR = '/content/'
MODEL_PATH = MODEL_DIR + 'model.pt' if MODEL_DIR.endswith('/') else MODEL_DIR + '/model.pt'

# %%
from _utils import load_data, Dataset, Dataloader, FCL_Tests, ReLU_Tests, SCE_Tests, plot_curves, plot_result
import numpy as np
import matplotlib.pyplot as plt
import random
import torch

# %%
if torch.cuda.is_available():
  DEVICE = 'cuda'
  print(f'Using torch {torch.__version__}, device = {torch.cuda.get_device_name(0)}')
else:
  DEVICE = 'cpu'
  print(f'Using torch {torch.__version__}, device = cpu')
# Out:
# Using torch 2.0.0+cu118, device = cpu

# %%
images, labels, classes = load_data()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar10/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 48898819.79it/s]
# Extracting ./cifar10/cifar-10-python.tar.gz to ./cifar10/

# %%
print(f'Data type of images: {images.dtype} (value range: [{images.min()}, {images.max()}])')
print(f'Shape of images: {images.shape}')
print(f'Shape of labels: {labels.shape}')
print(f'Number of classes: {len(classes)}')
print(f'Classes: {classes}')
# Out:
# Data type of images: uint8 (value range: [0, 255])
# Shape of images: (50000, 32, 32, 3)
# Shape of labels: (50000,)
# Number of classes: 10
# Classes: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Display samples of each class
plt.rcParams['figure.figsize'] = (16, 16)
num_classes = len(classes)
num_example = 10
for label, class_name in enumerate(classes):
  idxs = np.flatnonzero(labels == label)
  idxs = np.random.choice(idxs, num_example, replace=False)
  for i, idx in enumerate(idxs):
    plt_idx = i * num_classes + label + 1
    plt.subplot(num_example, num_classes, plt_idx)
    plt.imshow(images[idx]); plt.axis('off')
    if i == 0:
      plt.title(class_name)
plt.show()

# %%
# Data splitting with numpy array slicing
num_data = images.shape[0]
split_ratio = {'train': 0.6, 'valid': 0.2, 'test': 0.2}
num_valid_data = round(num_data * split_ratio['valid'])
num_test_data = round(num_data * split_ratio['test'])
num_train_data = num_data - (num_valid_data + num_test_data)

start_idx = 0
train_dataset = Dataset(images[start_idx:start_idx+num_train_data], labels[start_idx:start_idx+num_train_data])
start_idx += num_train_data

valid_dataset = Dataset(images[start_idx:start_idx+num_valid_data], labels[start_idx:start_idx+num_valid_data])
start_idx += num_valid_data

test_dataset = Dataset(images[start_idx:start_idx+num_test_data], labels[start_idx:start_idx+num_test_data])

print(f'Number of training data: {len(train_dataset)}')
print(f'Number of validation data: {len(valid_dataset)}')
print(f'Number of test data: {len(test_dataset)}')
# Out:
# Number of training data: 30000
# Number of validation data: 10000
# Number of test data: 10000

# %% [markdown]
# ## Layer Definition
# The architecture of our two-layer fully-connected neural network is like:
#
# Input $\rightarrow$ Fully-Connected Layer1 $\rightarrow$ ReLU  $\rightarrow$ Fully-Connected Layer2 $\rightarrow$ Softmax
#
# The learnable parameters are weights and bias of the two fully-connected layers. Let's name and clarify the parameters and their shapes:
#
# 1. Input data: $\mathbf{x}$, shape: ${N\times D}$
# 2. Weights of first fully-connected layer: $\mathbf{w_1}$, shape: ${D\times H}$
# 3. Bias of first fully-connected layer: $\mathbf{b_1}$, shape: ${H}$
# 4. Weights of second fully-connected layer: $\mathbf{w_2}$, shape: ${H\times C}$
# 5. Bias of second fully-connected layer: $\mathbf{b_2}$, shape: ${C}$
# 6. Output of the network: $\mathbf{S}$, shape: ${N\times C}$
#
# And then we can simply express the function of our network by:
# $$\mathbf{S} = \mathbf{w_2} * ReLU(\mathbf{w_1} * \mathbf{x} + \mathbf{b_1}) + \mathbf{b_2}$$
#
# Since the two fully-connected layers do the same job, that is, multiply weights with input and then plus bias, we define a class called FullyConnectedLayer to implement a single fully-connected layer.

# %%
class FullyConnectedLayer(object):
  def __init__(self, device='cpu'):
    self.dv = device
  def forward(self, x, w, b):
    N, D = x.shape
    Dw, F = w.shape
    assert Dw == D, f'Wrong shape of weights, expected ({D},{F}) but got ({Dw},{F})'
    Fb = b.shape[0]
    assert Fb == F, f'Wrong shape of bias, expected ({F},) but got ({Fb},)'
    out = torch.zeros((N, F)).to(self.dv)
    ####################
    # TODO:
    # 1. Implement fully connected layer with `w` * `x` + `b` and store the result in variable `out`
    ####################
    # -----START OF YOUR CODE-----
    out = torch.add(torch.matmul(x,w),b)
    # ------END OF YOUR CODE------
    self.cache = (x, w, b, out)
    return out
  def backward(self, backprop): # 分別計算loss對w和b的梯度並更新
    N, F = backprop.shape # F:神經元數
    dw = None
    db = None
    ####################
    # TODO:
    # 1. Derive the gradient of bias, i.e., d(out)/d(b)
    # 2. Multiply d(out)/d(b) with `backprop` due to chain rule, and then store the AVERAGED result in variable `db`
    # 3. Then, derive the gradient of weights, i.e., d(out)/d(w)
    # 4. Multiply d(out)/d(w) with `backprop` due to chain rule, and then store the AVERAGED result in variable `dw`
    # HINT: Shapes of `db` and `dw` should be (F,) and (D, F) respectively
    ####################
    # -----START OF YOUR CODE-----
    x, w, b, out = self.cache

    db = torch.sum(backprop,dim=0)/N # dim=0:縱向壓縮
    # print("db=",db)
    dw = torch.matmul(x.T,backprop)/N
    # print("dw=",dw)
    # ------END OF YOUR CODE------
    return dw, db

# %%
layer = FullyConnectedLayer()
FCL_Tests(layer)
# Out:
# Results of fully connected layer forward and backward tests: All passed.

# %% [markdown]
# ReLU (Rectified Linear Unit) is the currently most used non-linearity (or called activation function) in neural networks. Its formula as following:
# $$ReLU(t) = max(0, t)$$
#
# Since ReLU only allows positive values to be passed forward, any negative values of the input will not be able to propagate gradients during backpropagation.

# %%
class ReLU(object):
  def __init__(self):
    pass
  def forward(self, t):
    out = t.clone()
    ####################
    # TODO:
    # 1. Implement ReLU on `t` and store in variable `out`
    ####################
    # -----START OF YOUR CODE-----

    # x,y = out.shape
    # for i in range(x):
    #   for j in range(y):
    #     if out[i][j] < 0:
    #       out[i][j] = 0

    out[out<0]=0
    # ------END OF YOUR CODE------
    self.cache = (t, out)
    return out
  def backward(self, backprop):
    dt = torch.zeros_like(backprop)
    ####################
    # TODO:
    # 1. Derive d(out)/d(t)
    # 2. Multiply d(out)/d(t) with `backprop` due to chain rule, and then store the result in variable `dt`
    ####################
    # -----START OF YOUR CODE-----
    t,out = self.cache

    # for i in range(x):
    #   for j in range(y):
    #     if out[i][j] > 0:
    #       d_relu[i][j] = 1

    dt[out > 0] = 1 # out中元素>0的，d_relu中設成1
    # print("dt=",dt)
    # print("backprop",backprop)
    dt = dt * backprop # 每一項取and
    # print("new dt=",dt)

    # ------END OF YOUR CODE------
    return dt

# %%
layer = ReLU()
ReLU_Tests(layer)
# Out:
# Results of ReLU function tests: All passed.

# %% [markdown]
# Softmax is used to convert a vector of real numbers into a probability distribution over classes. It can be expressed mathematically as:
# $$softmax(\mathbf{S}_i)=\mathbf{p}_i=\frac{exp(\mathbf{S}_i)}{\sum_{j=1}^\mathbf{C}exp(\mathbf{S}_j)}$$
# And the cross-entropy loss, on the other hand, is a measure of the difference between the predicted probability distribution and the true probability distribution of the labels. Let $\mathbf{y}$ be **one-hot encoded** ground-truth label, that is, its shape would be the same with output of the network. Cross-entropy loss formula is defined as:
# $$CE = -\sum\mathbf{y}_i * log(\mathbf{p}_i)$$

# %%
class Softmax_CrossEntropy(object):
  def __init__(self):
    pass
  def forward(self, y, net_out):
    N, F = net_out.shape
    prob = torch.zeros_like(net_out)
    ####################
    # TODO:
    # 1. Implement Softmax and store the result in variable `prob`
    # HINT: Shape of `prob` should be (N, F)
    ####################
    # -----START OF YOUR CODE-----

    # print(torch.exp(net_out))
    # print("1:",torch.sum(torch.exp(net_out)))
    # print("2:",torch.sum(torch.exp(net_out),dim=1)) # 算完會轉成一列
    # print("3:",torch.sum(torch.exp(net_out),dim=1,keepdim=True))

    prob = torch.exp(net_out) / torch.sum(torch.exp(net_out),dim=1,keepdim=True)
    
    # ------END OF YOUR CODE------
    self.cache = (y, prob)
    pred_y = prob.argmax(dim=1)
    
    # 將標籤轉換為 one-hot 向量
    y_one_hot = torch.zeros_like(net_out)
    y_one_hot[np.arange(N), y] = 1

    loss = torch.zeros(1)
    ####################
    # TODO:
    # 1. Implement cross-entropy loss and store the result in variable `loss`
    ####################
    # -----START OF YOUR CODE-----
    # loss = -torch.sum(torch.log(prob)*pred_y + torch.log(torch.ones_like(prob)-prob)*(1-pred_y)) / N

    loss = -torch.sum(y_one_hot * torch.log(prob)) / N
    # ------END OF YOUR CODE------
    return pred_y, loss
  def backward(self):
    y, grad = self.cache
    N, F = grad.shape
    ####################
    # TODO:
    # 1. Derive the gradient of `net_out` and store the result in variable `grad`
    ####################
    # -----START OF YOUR CODE-----
    # grad_temp = grad
    grad[np.arange(N), y] -= 1
    grad = grad/N
    # grad=grad_temp
    # ------END OF YOUR CODE------
    return grad

# %%
layer = Softmax_CrossEntropy()
SCE_Tests(layer)
# Out:
# Results of softmax and cross entropy forward and backward tests: All passed.

# %% [markdown]
# ## Network Definition

# %%
class Classifier(object):
  def __init__(self, dim_in, dim_hidden, dim_out, device='cpu'):
    self.dv = device
    np.random.seed(0)
    self.params = {'w1': torch.from_numpy(np.random.randn(dim_in, dim_hidden)*0.8).to(self.dv),
             'b1': torch.zeros(dim_hidden).to(self.dv),
             'w2': torch.from_numpy(np.random.randn(dim_hidden, dim_out)*0.8).to(self.dv),
             'b2': torch.zeros(dim_out).to(self.dv)}
    layer1 = FullyConnectedLayer()
    activation = ReLU()
    layer2 = FullyConnectedLayer()
    self.net = [layer1, activation, layer2]
    self.loss_func = Softmax_CrossEntropy()
  def save_model(self, path):
    torch.save(self.params, path)
  def load_model(self, path):
    checkpoint = torch.load(path, map_location=self.dv)
    self.params = checkpoint
  def training(self, train_dataloader, valid_dataloader, epochs=200, learning_rate=1e-3, learning_rate_decay=0.95, verbose=1):
    print(f'Training with batch_size={train_dataloader[0][0].shape[0]}, hidden_dim={self.params["w1"].shape[1]}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}')
    train_loss_log = []
    train_acc_log = []
    valid_loss_log = []
    valid_acc_log = []
    best_val_loss = None
    for epoch in range(epochs):
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(f'Epoch {epoch+1}:')
      single_epoch_log = ''
      train_loss = 0.0
      train_corr = 0.0; train_eval = 0.0
      for batch_idx in range(len(train_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = train_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
        pred_y, loss = self.loss_func.forward(batch_label, layer2_out)
        train_loss += loss.cpu().numpy()
        train_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        train_eval += batch_img.shape[0]
        ### Backpropagation and Optimization ###
        params_grad = {}
        dloss_dout2 = self.loss_func.backward()
        dout2_dw2, dout2_db2 = self.net[2].backward(dloss_dout2)
        params_grad['w2'] = dout2_dw2; params_grad['b2'] = dout2_db2
        dout2_dout1 = self.net[1].backward(dloss_dout2.mm(self.params['w2'].T))
        dout1_dw1, dout1_db1 = self.net[0].backward(dout2_dout1)
        params_grad['w1'] = dout1_dw1; params_grad['b1'] = dout1_db1
        ####################
        # TODO:
        # 1. Update model parameters, i.e., `self.params`, by gradient descent
        ####################
        # -----START OF YOUR CODE-----
        grads = {}
        for k, v in params_grad.items():
            grads[k] = v / batch_img.shape[0]
        self.params['w1'] -= learning_rate * grads['w1']
        self.params['b1'] -= learning_rate * grads['b1']
        self.params['w2'] -= learning_rate * grads['w2']
        self.params['b2'] -= learning_rate * grads['b2']        

        # ------END OF YOUR CODE------
      train_loss_log.append(train_loss/train_eval)
      train_acc_log.append(100*train_corr/train_eval)
      single_epoch_log += f'Training accuracy: {format(train_acc_log[-1], ".2f")}%, loss: {format(train_loss_log[-1], ".4f")}\n'
      train_dataloader.shuffle()

      valid_loss = 0.0
      valid_corr = 0.0; valid_eval = 0.0
      for batch_idx in range(len(valid_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = valid_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
        pred_y, loss = self.loss_func.forward(batch_label, layer2_out)
        valid_loss += loss.cpu().numpy()
        valid_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        valid_eval += batch_img.shape[0]
      valid_loss_log.append(valid_loss/valid_eval)
      valid_acc_log.append(100*valid_corr/valid_eval)
      single_epoch_log += f'Validaion accuracy: {format(valid_acc_log[-1], ".2f")}%, loss: {format(valid_loss_log[-1], ".4f")}'
      if best_val_loss is None or valid_loss < best_val_loss:
        best_val_loss = valid_loss
        self.save_model(MODEL_PATH)
        if verbose == 1:
          single_epoch_log = '[MODEL SAVED]\n' + single_epoch_log
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(single_epoch_log)
      learning_rate *= learning_rate_decay # update learning_rate every epoch
    return train_loss_log,train_acc_log,valid_loss_log,valid_acc_log
  def test(self, test_dataloader):
    total_corr = 0; total_eval = 0
    for batch_idx in range(len(test_dataloader)):
      ### Model Input ###
      batch_data = test_dataloader[batch_idx]
      batch_img, batch_label = batch_data
      layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
      layer1_out = self.net[1].forward(layer1_out)
      layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
      pred_y, _ = self.loss_func.forward(batch_label, layer2_out)
      total_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
      total_eval += batch_img.shape[0]
    print(f'Got {total_corr} correct prediction in {total_eval} test data, accuracy: {format((total_corr*1.0/total_eval)*100, ".2f")}%')

# %% [markdown]
# ## Searching for Best Hyperparameters
# Hyperparameters are configuration variables that set by users before model training. They influence the learning process and the final performance of the model. The goal of selecting optimal hyperparameters is to improve the model's accuracy and generalization ability.
#
# Hyperparameters in this assignment include hidden layer size, batch size, learning rate, and learning rate decay. You may change candidate values of them in the following cells and observe which might be useful to optimize the model. Howerver,  as running the whole section may take a while, you are allowed to not running all of the cells.

# %%
# Configurations
IN_DIM = np.prod(images[0].shape)
OUT_DIM = len(classes)

# %%
# Hyperparameters
BATCH_SIZE = 16
LR = 1e-3
LR_DECAY = 0.95
HIDEEN_DIM = 64

# %%
lr_cand = [1e-2, 1e-3, 1e-4]
train_acc = []
valid_acc = []

for lr in lr_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=lr, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(lr_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=64, learning_rate=0.01, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.0001, learning_rate_decay=0.95

# %%
bs_cand = [8, 16, 100]
train_acc = []
valid_acc = []

for bs in bs_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=bs)
  valid_dataloader = Dataloader(valid_dataset, batch_size=bs)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(bs_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=8, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=100, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95

# %%
hd_cand = [32, 64, 256]
train_acc = []
valid_acc = []

for hd in hd_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, hd, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(hd_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=32, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=256, learning_rate=0.001, learning_rate_decay=0.95

# %%
lr_decay_cand = [1.0, 0.95, 0.9]
train_acc = []
valid_acc = []

for lrd in lr_decay_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=lrd, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(lr_decay_cand, train_acc, valid_acc)

# %% [markdown]
# ## Training with Best Hyperparameters

# %%
# Configurations
IN_DIM = np.prod(images[0].shape)
OUT_DIM = len(classes)

# %%
# Please set your hyperparameters here
BATCH_SIZE = 8 # 128
LR = 0.01 # 0.0001
LR_DECAY = 0.97
HIDEEN_DIM = 256

# %%
train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
train_loss, train_acc, valid_loss, valid_acc = model.training(train_dataloader, valid_dataloader, learning_rate=LR, learning_rate_decay=LR_DECAY)
plot_result(train_loss, train_acc, valid_loss, valid_acc)
# Out:
# Training with batch_size=8, hidden_dim=256, learning_rate=0.01, learning_rate_decay=0.97
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 19.86%, loss: nan
# Validaion accuracy: 18.13%, loss: 7.6831
# Epoch 2:
# [MODEL SAVED]
# Training accuracy: 27.60%, loss: 5.3977
# Validaion accuracy: 21.45%, loss: 6.1863
# Epoch 3:
# [MODEL SAVED]
# Training accuracy: 28.36%, loss: 4.6715
# Validaion accuracy: 23.18%, loss: 5.4022
# Epoch 4:
# [MODEL SAVED]
# Training accuracy: 29.51%, loss: 4.1096
# Validaion accuracy: 21.86%, loss: 5.2769
# Epoch 5:
# [MODEL SAVED]
# Training accuracy: 30.20%, loss: 3.6785
# Validaion accuracy: 23.34%, loss: 4.5704
# Epoch 6:
# [MODEL SAVED]
# Training accuracy: 31.29%, loss: 3.2283
# Validaion accuracy: 23.45%, loss: 4.3940
# Epoch 7:
# [MODEL SAVED]
# Training accuracy: 29.80%, loss: 3.2070
# Validaion accuracy: 24.63%, loss: 3.8122
# Epoch 8:
# [MODEL SAVED]
# Training accuracy: 31.29%, loss: 2.9542
# Validaion accuracy: 23.85%, loss: 3.6142
# Epoch 9:
# Training accuracy: 32.38%, loss: 2.6049
# Validaion accuracy: 24.34%, loss: 3.6315
# Epoch 10:
# [MODEL SAVED]
# Training accuracy: 32.36%, loss: 2.5384
# Validaion accuracy: 23.56%, loss: 3.4754
# Epoch 11:
# Training accuracy: 32.31%, loss: 2.3672
# Validaion accuracy: 22.14%, loss: 3.4837
# Epoch 12:
# [MODEL SAVED]
# Training accuracy: 33.32%, loss: 2.2394
# Validaion accuracy: 25.26%, loss: 2.8290
# Epoch 13:
# [MODEL SAVED]
# Training accuracy: 32.89%, loss: 2.1859
# Validaion accuracy: 26.81%, loss: 2.7182
# Epoch 14:
# [MODEL SAVED]
# Training accuracy: 32.46%, loss: 2.0629
# Validaion accuracy: 26.11%, loss: 2.5928
# Epoch 15:
# [MODEL SAVED]
# Training accuracy: 32.02%, loss: 1.9786
# Validaion accuracy: 26.07%, loss: 2.5390
# Epoch 16:
# [MODEL SAVED]
# Training accuracy: 32.69%, loss: 1.9104
# Validaion accuracy: 25.63%, loss: 2.4170
# Epoch 17:
# [MODEL SAVED]
# Training accuracy: 32.04%, loss: 1.8235
# Validaion accuracy: 25.77%, loss: 2.2559
# Epoch 18:
# [MODEL SAVED]
# Training accuracy: 33.59%, loss: 1.7036
# Validaion accuracy: 25.51%, loss: 2.2147
# Epoch 19:
# [MODEL SAVED]
# Training accuracy: 34.42%, loss: 1.6256
# Validaion accuracy: 25.72%, loss: 2.1680
# Epoch 20:
# [MODEL SAVED]
# Training accuracy: 33.30%, loss: 1.5802
# Validaion accuracy: 25.55%, loss: 2.0170
# Epoch 21:
# Training accuracy: 33.65%, loss: 1.4830
# Validaion accuracy: 25.16%, loss: 2.0621
# Epoch 22:
# [MODEL SAVED]
# Training accuracy: 33.33%, loss: 1.4622
# Validaion accuracy: 25.30%, loss: 1.8353
# Epoch 23:
# [MODEL SAVED]
# Training accuracy: 31.45%, loss: 1.4310
# Validaion accuracy: 26.41%, loss: 1.7959
# Epoch 24:
# [MODEL SAVED]
# Training accuracy: 33.21%, loss: 1.3507
# Validaion accuracy: 26.20%, loss: 1.7295
# Epoch 25:
# [MODEL SAVED]
# Training accuracy: 32.86%, loss: 1.3348
# Validaion accuracy: 27.08%, loss: 1.6241
# Epoch 26:
# [MODEL SAVED]
# Training accuracy: 32.92%, loss: 1.2870
# Validaion accuracy: 26.77%, loss: 1.5832
# Epoch 27:
# [MODEL SAVED]
# Training accuracy: 33.66%, loss: 1.2185
# Validaion accuracy: 26.03%, loss: 1.5688
# Epoch 28:
# [MODEL SAVED]
# Training accuracy: 31.88%, loss: 1.2336
# Validaion accuracy: 26.68%, loss: 1.4823
# Epoch 29:
# Training accuracy: 32.28%, loss: 1.1355
# Validaion accuracy: 26.41%, loss: 1.5079
# Epoch 30:
# [MODEL SAVED]
# Training accuracy: 34.68%, loss: 1.0997
# Validaion accuracy: 27.49%, loss: 1.4664
# Epoch 31:
# [MODEL SAVED]
# Training accuracy: 31.89%, loss: 1.0999
# Validaion accuracy: 26.28%, loss: 1.3844
# Epoch 32:
# [MODEL SAVED]
# Training accuracy: 32.61%, loss: 1.0924
# Validaion accuracy: 25.84%, loss: 1.3504
# Epoch 33:
# [MODEL SAVED]
# Training accuracy: 33.04%, loss: 1.0629
# Validaion accuracy: 25.43%, loss: 1.2991
# Epoch 34:
# Training accuracy: 33.14%, loss: 0.9943
# Validaion accuracy: 24.74%, loss: 1.3687
# Epoch 35:
# [MODEL SAVED]
# Training accuracy: 32.53%, loss: 0.9765
# Validaion accuracy: 27.48%, loss: 1.2093
# Epoch 36:
# [MODEL SAVED]
# Training accuracy: 32.23%, loss: 0.9565
# Validaion accuracy: 27.82%, loss: 1.1284
# Epoch 37:
# Training accuracy: 34.44%, loss: 0.8895
# Validaion accuracy: 27.00%, loss: 1.1321
# Epoch 38:
# Training accuracy: 33.66%, loss: 0.8822
# Validaion accuracy: 26.69%, loss: 1.2030
# Epoch 39:
# [MODEL SAVED]
# Training accuracy: 33.79%, loss: 0.8819
# Validaion accuracy: 26.21%, loss: 1.1234
# Epoch 40:
# [MODEL SAVED]
# Training accuracy: 33.56%, loss: 0.8516
# Validaion accuracy: 27.30%, loss: 1.0600
# Epoch 41:
# [MODEL SAVED]
# Training accuracy: 33.67%, loss: 0.8057
# Validaion accuracy: 27.38%, loss: 1.0488
# Epoch 42:
# [MODEL SAVED]
# Training accuracy: 33.59%, loss: 0.8251
# Validaion accuracy: 25.64%, loss: 1.0295
# Epoch 43:
# Training accuracy: 34.16%, loss: 0.8135
# Validaion accuracy: 25.30%, loss: 1.0405
# Epoch 44:
# [MODEL SAVED]
# Training accuracy: 33.52%, loss: 0.7624
# Validaion accuracy: 25.96%, loss: 0.9800
# Epoch 45:
# Training accuracy: 33.21%, loss: 0.7719
# Validaion accuracy: 26.66%, loss: 0.9867
# Epoch 46:
# Training accuracy: 33.34%, loss: 0.7610
# Validaion accuracy: 25.32%, loss: 1.0121
# Epoch 47:
# [MODEL SAVED]
# Training accuracy: 33.93%, loss: 0.7096
# Validaion accuracy: 26.23%, loss: 0.9586
# Epoch 48:
# [MODEL SAVED]
# Training accuracy: 32.69%, loss: 0.7291
# Validaion accuracy: 26.86%, loss: 0.9007
# Epoch 49:
# Training accuracy: 33.95%, loss: 0.7036
# Validaion accuracy: 26.92%, loss: 0.9022
# Epoch 50:
# [MODEL SAVED]
# Training accuracy: 32.77%, loss: 0.6960
# Validaion accuracy: 26.43%, loss: 0.8741
# Epoch 51:
# [MODEL SAVED]
# Training accuracy: 32.73%, loss: 0.6887
# Validaion accuracy: 26.44%, loss: 0.8666
# Epoch 52:
# [MODEL SAVED]
# Training accuracy: 33.12%, loss: 0.6961
# Validaion accuracy: 27.12%, loss: 0.8136
# Epoch 53:
# Training accuracy: 33.04%, loss: 0.6522
# Validaion accuracy: 26.33%, loss: 0.8554
# Epoch 54:
# [MODEL SAVED]
# Training accuracy: 32.92%, loss: 0.6623
# Validaion accuracy: 27.06%, loss: 0.7847
# Epoch 55:
# Training accuracy: 34.38%, loss: 0.6306
# Validaion accuracy: 27.63%, loss: 0.8093
# Epoch 56:
# [MODEL SAVED]
# Training accuracy: 33.90%, loss: 0.6204
# Validaion accuracy: 26.58%, loss: 0.7712
# Epoch 57:
# Training accuracy: 32.81%, loss: 0.6396
# Validaion accuracy: 28.16%, loss: 0.7743
# Epoch 58:
# [MODEL SAVED]
# Training accuracy: 31.90%, loss: 0.6158
# Validaion accuracy: 26.35%, loss: 0.7585
# Epoch 59:
# [MODEL SAVED]
# Training accuracy: 32.19%, loss: 0.6160
# Validaion accuracy: 28.57%, loss: 0.7274
# Epoch 60:
# Training accuracy: 32.06%, loss: 0.6012
# Validaion accuracy: 25.81%, loss: 0.7319
# Epoch 61:
# Training accuracy: 33.06%, loss: 0.5920
# Validaion accuracy: 26.68%, loss: 0.7650
# Epoch 62:
# Training accuracy: 33.93%, loss: 0.5763
# Validaion accuracy: 27.57%, loss: 0.7379
# Epoch 63:
# [MODEL SAVED]
# Training accuracy: 33.78%, loss: 0.5917
# Validaion accuracy: 26.81%, loss: 0.6961
# Epoch 64:
# [MODEL SAVED]
# Training accuracy: 32.65%, loss: 0.5661
# Validaion accuracy: 26.83%, loss: 0.6771
# Epoch 65:
# Training accuracy: 32.53%, loss: 0.5630
# Validaion accuracy: 26.17%, loss: 0.6942
# Epoch 66:
# Training accuracy: 32.32%, loss: 0.5737
# Validaion accuracy: 25.54%, loss: 0.7183
# Epoch 67:
# Training accuracy: 31.96%, loss: 0.5521
# Validaion accuracy: 26.74%, loss: 0.6774
# Epoch 68:
# [MODEL SAVED]
# Training accuracy: 33.77%, loss: 0.5376
# Validaion accuracy: 27.73%, loss: 0.6472
# Epoch 69:
# Training accuracy: 31.90%, loss: 0.5351
# Validaion accuracy: 27.95%, loss: 0.6823
# Epoch 70:
# [MODEL SAVED]
# Training accuracy: 33.92%, loss: 0.5281
# Validaion accuracy: 26.29%, loss: 0.6391
# Epoch 71:
# Training accuracy: 32.13%, loss: 0.5272
# Validaion accuracy: 26.83%, loss: 0.6464
# Epoch 72:
# [MODEL SAVED]
# Training accuracy: 31.49%, loss: 0.5407
# Validaion accuracy: 25.88%, loss: 0.6263
# Epoch 73:
# [MODEL SAVED]
# Training accuracy: 32.39%, loss: 0.5328
# Validaion accuracy: 26.85%, loss: 0.6256
# Epoch 74:
# Training accuracy: 31.83%, loss: 0.5333
# Validaion accuracy: 25.01%, loss: 0.6388
# Epoch 75:
# [MODEL SAVED]
# Training accuracy: 32.26%, loss: 0.5157
# Validaion accuracy: 25.65%, loss: 0.6179
# Epoch 76:
# [MODEL SAVED]
# Training accuracy: 32.33%, loss: 0.5155
# Validaion accuracy: 26.75%, loss: 0.5864
# Epoch 77:
# Training accuracy: 31.98%, loss: 0.5029
# Validaion accuracy: 27.39%, loss: 0.5867
# Epoch 78:
# Training accuracy: 32.90%, loss: 0.5194
# Validaion accuracy: 25.22%, loss: 0.6012
# Epoch 79:
# Training accuracy: 32.77%, loss: 0.5001
# Validaion accuracy: 25.46%, loss: 0.5930
# Epoch 80:
# [MODEL SAVED]
# Training accuracy: 32.99%, loss: 0.5058
# Validaion accuracy: 25.30%, loss: 0.5759
# Epoch 81:
# [MODEL SAVED]
# Training accuracy: 30.99%, loss: 0.5159
# Validaion accuracy: 25.98%, loss: 0.5714
# Epoch 82:
# [MODEL SAVED]
# Training accuracy: 31.77%, loss: 0.4909
# Validaion accuracy: 27.70%, loss: 0.5585
# Epoch 83:
# [MODEL SAVED]
# Training accuracy: 32.28%, loss: 0.4860
# Validaion accuracy: 28.59%, loss: 0.5548
# Epoch 84:
# [MODEL SAVED]
# Training accuracy: 31.32%, loss: 0.4981
# Validaion accuracy: 27.07%, loss: 0.5447
# Epoch 85:
# Training accuracy: 31.90%, loss: 0.4786
# Validaion accuracy: 27.98%, loss: 0.5707
# Epoch 86:
# Training accuracy: 32.42%, loss: 0.4653
# Validaion accuracy: 26.29%, loss: 0.5600
# Epoch 87:
# Training accuracy: 32.16%, loss: 0.4790
# Validaion accuracy: 25.56%, loss: 0.5735
# Epoch 88:
# [MODEL SAVED]
# Training accuracy: 31.05%, loss: 0.4829
# Validaion accuracy: 29.07%, loss: 0.5404
# Epoch 89:
# Training accuracy: 31.78%, loss: 0.4728
# Validaion accuracy: 27.55%, loss: 0.5436
# Epoch 90:
# Training accuracy: 32.09%, loss: 0.4663
# Validaion accuracy: 27.09%, loss: 0.5465
# Epoch 91:
# [MODEL SAVED]
# Training accuracy: 32.91%, loss: 0.4520
# Validaion accuracy: 26.66%, loss: 0.5381
# Epoch 92:
# [MODEL SAVED]
# Training accuracy: 31.98%, loss: 0.4747
# Validaion accuracy: 28.52%, loss: 0.5376
# Epoch 93:
# [MODEL SAVED]
# Training accuracy: 33.38%, loss: 0.4502
# Validaion accuracy: 29.41%, loss: 0.5168
# Epoch 94:
# Training accuracy: 31.90%, loss: 0.4724
# Validaion accuracy: 27.48%, loss: 0.5285
# Epoch 95:
# Training accuracy: 32.01%, loss: 0.4564
# Validaion accuracy: 26.20%, loss: 0.5188
# Epoch 96:
# [MODEL SAVED]
# Training accuracy: 30.46%, loss: 0.4448
# Validaion accuracy: 26.98%, loss: 0.5148
# Epoch 97:
# [MODEL SAVED]
# Training accuracy: 31.71%, loss: 0.4675
# Validaion accuracy: 28.51%, loss: 0.5118
# Epoch 98:
# Training accuracy: 31.34%, loss: 0.4460
# Validaion accuracy: 29.07%, loss: 0.5131
# Epoch 99:
# Training accuracy: 30.98%, loss: 0.4593
# Validaion accuracy: 25.78%, loss: 0.5282
# Epoch 100:
# [MODEL SAVED]
# Training accuracy: 32.42%, loss: 0.4575
# Validaion accuracy: 27.39%, loss: 0.5061
# Epoch 101:
# Training accuracy: 31.92%, loss: 0.4601
# Validaion accuracy: 27.71%, loss: 0.5065
# Epoch 102:
# [MODEL SAVED]
# Training accuracy: 31.60%, loss: 0.4499
# Validaion accuracy: 26.14%, loss: 0.5034
# Epoch 103:
# Training accuracy: 32.53%, loss: 0.4365
# Validaion accuracy: 26.82%, loss: 0.5062
# Epoch 104:
# [MODEL SAVED]
# Training accuracy: 31.53%, loss: 0.4355
# Validaion accuracy: 26.99%, loss: 0.5032
# Epoch 105:
# [MODEL SAVED]
# Training accuracy: 32.17%, loss: 0.4377
# Validaion accuracy: 28.42%, loss: 0.4975
# Epoch 106:
# Training accuracy: 32.00%, loss: 0.4366
# Validaion accuracy: 28.82%, loss: 0.5012
# Epoch 107:
# Training accuracy: 32.37%, loss: 0.4356
# Validaion accuracy: 26.26%, loss: 0.4989
# Epoch 108:
# [MODEL SAVED]
# Training accuracy: 31.80%, loss: 0.4390
# Validaion accuracy: 27.79%, loss: 0.4942
# Epoch 109:
# [MODEL SAVED]
# Training accuracy: 30.40%, loss: 0.4356
# Validaion accuracy: 27.14%, loss: 0.4864
# Epoch 110:
# Training accuracy: 31.36%, loss: 0.4340
# Validaion accuracy: 27.63%, loss: 0.4879
# Epoch 111:
# [MODEL SAVED]
# Training accuracy: 30.71%, loss: 0.4397
# Validaion accuracy: 27.95%, loss: 0.4860
# Epoch 112:
# Training accuracy: 31.27%, loss: 0.4489
# Validaion accuracy: 27.30%, loss: 0.4964
# Epoch 113:
# Training accuracy: 29.83%, loss: 0.4523
# Validaion accuracy: 28.75%, loss: 0.4914
# Epoch 114:
# [MODEL SAVED]
# Training accuracy: 32.27%, loss: 0.4225
# Validaion accuracy: 27.39%, loss: 0.4840
# Epoch 115:
# Training accuracy: 31.75%, loss: 0.4352
# Validaion accuracy: 26.98%, loss: 0.4841
# Epoch 116:
# [MODEL SAVED]
# Training accuracy: 31.17%, loss: 0.4237
# Validaion accuracy: 27.15%, loss: 0.4777
# Epoch 117:
# [MODEL SAVED]
# Training accuracy: 30.52%, loss: 0.4418
# Validaion accuracy: 28.27%, loss: 0.4740
# Epoch 118:
# [MODEL SAVED]
# Training accuracy: 32.26%, loss: 0.4223
# Validaion accuracy: 28.26%, loss: 0.4738
# Epoch 119:
# Training accuracy: 31.31%, loss: 0.4246
# Validaion accuracy: 28.19%, loss: 0.4795
# Epoch 120:
# Training accuracy: 31.43%, loss: 0.4128
# Validaion accuracy: 27.78%, loss: 0.4771
# Epoch 121:
# [MODEL SAVED]
# Training accuracy: 30.64%, loss: 0.4363
# Validaion accuracy: 29.15%, loss: 0.4694
# Epoch 122:
# Training accuracy: 31.07%, loss: 0.4271
# Validaion accuracy: 28.11%, loss: 0.4781
# Epoch 123:
# Training accuracy: 31.59%, loss: 0.4179
# Validaion accuracy: 28.44%, loss: 0.4788
# Epoch 124:
# Training accuracy: 30.56%, loss: 0.4207
# Validaion accuracy: 27.62%, loss: 0.4763
# Epoch 125:
# [MODEL SAVED]
# Training accuracy: 31.33%, loss: 0.4309
# Validaion accuracy: 28.93%, loss: 0.4659
# Epoch 126:
# Training accuracy: 31.00%, loss: 0.4373
# Validaion accuracy: 27.95%, loss: 0.4700
# Epoch 127:
# Training accuracy: 32.26%, loss: 0.4074
# Validaion accuracy: 28.11%, loss: 0.4671
# Epoch 128:
# [MODEL SAVED]
# Training accuracy: 31.32%, loss: 0.4179
# Validaion accuracy: 28.91%, loss: 0.4648
# Epoch 129:
# [MODEL SAVED]
# Training accuracy: 30.55%, loss: 0.4327
# Validaion accuracy: 28.77%, loss: 0.4635
# Epoch 130:
# Training accuracy: 31.20%, loss: 0.4205
# Validaion accuracy: 27.87%, loss: 0.4670
# Epoch 131:
# [MODEL SAVED]
# Training accuracy: 31.80%, loss: 0.4217
# Validaion accuracy: 29.31%, loss: 0.4607
# Epoch 132:
# Training accuracy: 31.23%, loss: 0.4275
# Validaion accuracy: 28.03%, loss: 0.4607
# Epoch 133:
# Training accuracy: 30.42%, loss: 0.4309
# Validaion accuracy: 28.18%, loss: 0.4644
# Epoch 134:
# Training accuracy: 31.10%, loss: 0.4225
# Validaion accuracy: 27.50%, loss: 0.4621
# Epoch 135:
# Training accuracy: 30.84%, loss: 0.4186
# Validaion accuracy: 28.03%, loss: 0.4622
# Epoch 136:
# [MODEL SAVED]
# Training accuracy: 31.61%, loss: 0.4174
# Validaion accuracy: 28.11%, loss: 0.4559
# Epoch 137:
# Training accuracy: 30.54%, loss: 0.4069
# Validaion accuracy: 28.18%, loss: 0.4593
# Epoch 138:
# Training accuracy: 30.69%, loss: 0.3980
# Validaion accuracy: 28.91%, loss: 0.4561
# Epoch 139:
# Training accuracy: 32.06%, loss: 0.4076
# Validaion accuracy: 29.15%, loss: 0.4572
# Epoch 140:
# [MODEL SAVED]
# Training accuracy: 30.47%, loss: 0.4136
# Validaion accuracy: 29.07%, loss: 0.4537
# Epoch 141:
# Training accuracy: 31.63%, loss: 0.4116
# Validaion accuracy: 28.03%, loss: 0.4554
# Epoch 142:
# Training accuracy: 31.53%, loss: 0.4092
# Validaion accuracy: 29.39%, loss: 0.4558
# Epoch 143:
# Training accuracy: 30.78%, loss: 0.4131
# Validaion accuracy: 28.83%, loss: 0.4559
# Epoch 144:
# [MODEL SAVED]
# Training accuracy: 30.94%, loss: 0.4320
# Validaion accuracy: 28.75%, loss: 0.4535
# Epoch 145:
# Training accuracy: 30.67%, loss: 0.4072
# Validaion accuracy: 28.99%, loss: 0.4545
# Epoch 146:
# [MODEL SAVED]
# Training accuracy: 31.37%, loss: 0.4074
# Validaion accuracy: 28.75%, loss: 0.4532
# Epoch 147:
# Training accuracy: 31.88%, loss: 0.4220
# Validaion accuracy: 28.10%, loss: 0.4545
# Epoch 148:
# [MODEL SAVED]
# Training accuracy: 30.27%, loss: 0.4197
# Validaion accuracy: 28.43%, loss: 0.4518
# Epoch 149:
# Training accuracy: 31.48%, loss: 0.4347
# Validaion accuracy: 29.15%, loss: 0.4537
# Epoch 150:
# [MODEL SAVED]
# Training accuracy: 32.21%, loss: 0.4097
# Validaion accuracy: 28.75%, loss: 0.4506
# Epoch 151:
# Training accuracy: 30.24%, loss: 0.4211
# Validaion accuracy: 28.35%, loss: 0.4529
# Epoch 152:
# Training accuracy: 30.17%, loss: 0.4395
# Validaion accuracy: 28.43%, loss: 0.4511
# Epoch 153:
# [MODEL SAVED]
# Training accuracy: 30.90%, loss: 0.4171
# Validaion accuracy: 28.43%, loss: 0.4496
# Epoch 154:
# Training accuracy: 31.11%, loss: 0.4107
# Validaion accuracy: 28.11%, loss: 0.4516
# Epoch 155:
# [MODEL SAVED]
# Training accuracy: 30.58%, loss: 0.4134
# Validaion accuracy: 29.07%, loss: 0.4493
# Epoch 156:
# [MODEL SAVED]
# Training accuracy: 31.52%, loss: 0.4121
# Validaion accuracy: 28.91%, loss: 0.4469
# Epoch 157:
# Training accuracy: 30.12%, loss: 0.4330
# Validaion accuracy: 28.03%, loss: 0.4493
# Epoch 158:
# Training accuracy: 30.25%, loss: 0.4177
# Validaion accuracy: 27.95%, loss: 0.4481
# Epoch 159:
# Training accuracy: 30.77%, loss: 0.4157
# Validaion accuracy: 28.03%, loss: 0.4508
# Epoch 160:
# [MODEL SAVED]
# Training accuracy: 31.13%, loss: 0.4319
# Validaion accuracy: 29.71%, loss: 0.4468
# Epoch 161:
# Training accuracy: 30.99%, loss: 0.4095
# Validaion accuracy: 28.75%, loss: 0.4470
# Epoch 162:
# [MODEL SAVED]
# Training accuracy: 31.24%, loss: 0.4111
# Validaion accuracy: 29.15%, loss: 0.4462
# Epoch 163:
# Training accuracy: 31.63%, loss: 0.4074
# Validaion accuracy: 29.55%, loss: 0.4463
# Epoch 164:
# Training accuracy: 31.27%, loss: 0.4072
# Validaion accuracy: 28.02%, loss: 0.4475
# Epoch 165:
# [MODEL SAVED]
# Training accuracy: 32.27%, loss: 0.4075
# Validaion accuracy: 29.55%, loss: 0.4445
# Epoch 166:
# Training accuracy: 30.50%, loss: 0.4038
# Validaion accuracy: 28.93%, loss: 0.4473
# Epoch 167:
# Training accuracy: 29.89%, loss: 0.4087
# Validaion accuracy: 28.03%, loss: 0.4472
# Epoch 168:
# [MODEL SAVED]
# Training accuracy: 32.30%, loss: 0.3960
# Validaion accuracy: 28.91%, loss: 0.4443
# Epoch 169:
# Training accuracy: 29.66%, loss: 0.4140
# Validaion accuracy: 29.15%, loss: 0.4456
# Epoch 170:
# [MODEL SAVED]
# Training accuracy: 31.32%, loss: 0.4255
# Validaion accuracy: 28.59%, loss: 0.4443
# Epoch 171:
# Training accuracy: 30.85%, loss: 0.4222
# Validaion accuracy: 28.03%, loss: 0.4449
# Epoch 172:
# Training accuracy: 31.40%, loss: 0.4072
# Validaion accuracy: 29.15%, loss: 0.4456
# Epoch 173:
# [MODEL SAVED]
# Training accuracy: 30.08%, loss: 0.4119
# Validaion accuracy: 29.79%, loss: 0.4424
# Epoch 174:
# Training accuracy: 31.15%, loss: 0.4071
# Validaion accuracy: 29.31%, loss: 0.4444
# Epoch 175:
# Training accuracy: 31.02%, loss: 0.4048
# Validaion accuracy: 28.67%, loss: 0.4433
# Epoch 176:
# Training accuracy: 31.76%, loss: 0.3909
# Validaion accuracy: 29.23%, loss: 0.4434
# Epoch 177:
# [MODEL SAVED]
# Training accuracy: 30.02%, loss: 0.4131
# Validaion accuracy: 29.31%, loss: 0.4419
# Epoch 178:
# Training accuracy: 32.04%, loss: 0.4091
# Validaion accuracy: 29.47%, loss: 0.4427
# Epoch 179:
# Training accuracy: 32.09%, loss: 0.4080
# Validaion accuracy: 28.83%, loss: 0.4428
# Epoch 180:
# Training accuracy: 30.01%, loss: 0.4180
# Validaion accuracy: 28.83%, loss: 0.4428
# Epoch 181:
# [MODEL SAVED]
# Training accuracy: 29.67%, loss: 0.4201
# Validaion accuracy: 29.97%, loss: 0.4412
# Epoch 182:
# Training accuracy: 29.89%, loss: 0.4261
# Validaion accuracy: 29.39%, loss: 0.4429
# Epoch 183:
# Training accuracy: 30.89%, loss: 0.4013
# Validaion accuracy: 28.99%, loss: 0.4430
# Epoch 184:
# Training accuracy: 31.54%, loss: 0.4204
# Validaion accuracy: 29.39%, loss: 0.4420
# Epoch 185:
# Training accuracy: 30.35%, loss: 0.4110
# Validaion accuracy: 28.67%, loss: 0.4422
# Epoch 186:
# Training accuracy: 30.70%, loss: 0.4044
# Validaion accuracy: 28.43%, loss: 0.4431
# Epoch 187:
# Training accuracy: 30.72%, loss: 0.4152
# Validaion accuracy: 28.67%, loss: 0.4417
# Epoch 188:
# [MODEL SAVED]
# Training accuracy: 30.32%, loss: 0.4144
# Validaion accuracy: 28.83%, loss: 0.4410
# Epoch 189:
# [MODEL SAVED]
# Training accuracy: 30.70%, loss: 0.4061
# Validaion accuracy: 28.51%, loss: 0.4404
# Epoch 190:
# Training accuracy: 30.92%, loss: 0.4150
# Validaion accuracy: 28.99%, loss: 0.4405
# Epoch 191:
# Training accuracy: 30.98%, loss: 0.4079
# Validaion accuracy: 29.07%, loss: 0.4405
# Epoch 192:
# Training accuracy: 30.36%, loss: 0.4136
# Validaion accuracy: 28.67%, loss: 0.4410
# Epoch 193:
# [MODEL SAVED]
# Training accuracy: 30.73%, loss: 0.4072
# Validaion accuracy: 29.71%, loss: 0.4400
# Epoch 194:
# [MODEL SAVED]
# Training accuracy: 31.88%, loss: 0.3956
# Validaion accuracy: 29.31%, loss: 0.4399
# Epoch 195:
# Training accuracy: 31.04%, loss: 0.4073
# Validaion accuracy: 28.19%, loss: 0.4427
# Epoch 196:
# Training accuracy: 29.94%, loss: 0.4136
# Validaion accuracy: 28.51%, loss: 0.4416
# Epoch 197:
# Training accuracy: 30.05%, loss: 0.4082
# Validaion accuracy: 28.91%, loss: 0.4402
# Epoch 198:
# [MODEL SAVED]
# Training accuracy: 30.71%, loss: 0.4079
# Validaion accuracy: 29.23%, loss: 0.4397
# Epoch 199:
# Training accuracy: 29.95%, loss: 0.4171
# Validaion accuracy: 29.07%, loss: 0.4415
# Epoch 200:
# [MODEL SAVED]
# Training accuracy: 31.04%, loss: 0.4101
# Validaion accuracy: 29.07%, loss: 0.4395

# %% [markdown]
# Test the model with test_dataset. <font color='red'>The test accuracy must reach at least 28%.</font>

# %%
test_dataloader = Dataloader(test_dataset)
model.load_model(MODEL_PATH)
model.test(test_dataloader)
# Out:
# Got 2966 correct prediction in 10000 test data, accuracy: 29.66%
