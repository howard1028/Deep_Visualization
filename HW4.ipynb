# %% [markdown]
# <a href="https://colab.research.google.com/github/howard1028/Deep_Visualization/blob/main/HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Network for CIFAR10 Classification
# In this assignment, we will implement a two-layer fully-connected neural network for CIFAR10 classification.

# %% [markdown]
# ## Data Preparation and Visualization

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# import sys
# sys.path.append('I:\HW4_2\HW4')

# %%
# You may change `MODEL_DIR` to a existing local directory if you are not using Colab
MODEL_DIR = r'I:\HW4_2\HW4'
MODEL_PATH = MODEL_DIR + 'model.pt' if MODEL_DIR.endswith('/') else MODEL_DIR + '/model.pt'

# %%
from _utils import load_data, Dataset, Dataloader, FCL_Tests, ReLU_Tests, SCE_Tests, plot_curves, plot_result
import numpy as np
import matplotlib.pyplot as plt
import random
import torch

# %%
if torch.cuda.is_available():
  DEVICE = 'cuda'
  print(f'Using torch {torch.__version__}, device = {torch.cuda.get_device_name(0)}')
else:
  DEVICE = 'cpu'
  print(f'Using torch {torch.__version__}, device = cpu')
# Out:
# Using torch 1.13.1+cu117, device = NVIDIA GeForce GTX 1080 Ti

# %%
images, labels, classes = load_data()
# Out:
# Files already downloaded and verified

# %%
print(f'Data type of images: {images.dtype} (value range: [{images.min()}, {images.max()}])')
print(f'Shape of images: {images.shape}')
print(f'Shape of labels: {labels.shape}')
print(f'Number of classes: {len(classes)}')
print(f'Classes: {classes}')
# Out:
# Data type of images: uint8 (value range: [0, 255])
# Shape of images: (50000, 32, 32, 3)
# Shape of labels: (50000,)
# Number of classes: 10
# Classes: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Display samples of each class
plt.rcParams['figure.figsize'] = (16, 16)
num_classes = len(classes)
num_example = 10
for label, class_name in enumerate(classes):
  idxs = np.flatnonzero(labels == label)
  idxs = np.random.choice(idxs, num_example, replace=False)
  for i, idx in enumerate(idxs):
    plt_idx = i * num_classes + label + 1
    plt.subplot(num_example, num_classes, plt_idx)
    plt.imshow(images[idx]); plt.axis('off')
    if i == 0:
      plt.title(class_name)
plt.show()

# %%
# Data splitting with numpy array slicing
num_data = images.shape[0]
split_ratio = {'train': 0.6, 'valid': 0.2, 'test': 0.2}
num_valid_data = round(num_data * split_ratio['valid'])
num_test_data = round(num_data * split_ratio['test'])
num_train_data = num_data - (num_valid_data + num_test_data)

start_idx = 0
train_dataset = Dataset(images[start_idx:start_idx+num_train_data], labels[start_idx:start_idx+num_train_data])
start_idx += num_train_data

valid_dataset = Dataset(images[start_idx:start_idx+num_valid_data], labels[start_idx:start_idx+num_valid_data])
start_idx += num_valid_data

test_dataset = Dataset(images[start_idx:start_idx+num_test_data], labels[start_idx:start_idx+num_test_data])

print(f'Number of training data: {len(train_dataset)}')
print(f'Number of validation data: {len(valid_dataset)}')
print(f'Number of test data: {len(test_dataset)}')
# Out:
# Number of training data: 30000
# Number of validation data: 10000
# Number of test data: 10000

# %% [markdown]
# ## Layer Definition
# The architecture of our two-layer fully-connected neural network is like:
#
# Input $\rightarrow$ Fully-Connected Layer1 $\rightarrow$ ReLU  $\rightarrow$ Fully-Connected Layer2 $\rightarrow$ Softmax
#
# The learnable parameters are weights and bias of the two fully-connected layers. Let's name and clarify the parameters and their shapes:
#
# 1. Input data: $\mathbf{x}$, shape: ${N\times D}$
# 2. Weights of first fully-connected layer: $\mathbf{w_1}$, shape: ${D\times H}$
# 3. Bias of first fully-connected layer: $\mathbf{b_1}$, shape: ${H}$
# 4. Weights of second fully-connected layer: $\mathbf{w_2}$, shape: ${H\times C}$
# 5. Bias of second fully-connected layer: $\mathbf{b_2}$, shape: ${C}$
# 6. Output of the network: $\mathbf{S}$, shape: ${N\times C}$
#
# And then we can simply express the function of our network by:
# $$\mathbf{S} = \mathbf{w_2} * ReLU(\mathbf{w_1} * \mathbf{x} + \mathbf{b_1}) + \mathbf{b_2}$$
#
# Since the two fully-connected layers do the same job, that is, multiply weights with input and then plus bias, we define a class called FullyConnectedLayer to implement a single fully-connected layer.

# %%
class FullyConnectedLayer(object):
  def __init__(self, device='cpu'):
    self.dv = device
  def forward(self, x, w, b):
    N, D = x.shape
    Dw, F = w.shape
    assert Dw == D, f'Wrong shape of weights, expected ({D},{F}) but got ({Dw},{F})'
    Fb = b.shape[0]
    assert Fb == F, f'Wrong shape of bias, expected ({F},) but got ({Fb},)'
    out = torch.zeros((N, F)).to(self.dv)
    ####################
    # TODO:
    # 1. Implement fully connected layer with `w` * `x` + `b` and store the result in variable `out`
    ####################
    # -----START OF YOUR CODE-----
    out = torch.add(torch.matmul(x,w),b)
    # ------END OF YOUR CODE------
    self.cache = (x, w, b, out)
    return out
  def backward(self, backprop): # 分別計算loss對w和b的梯度並更新
    N, F = backprop.shape # F:神經元數
    dw = None
    db = None
    ####################
    # TODO:
    # 1. Derive the gradient of bias, i.e., d(out)/d(b)
    # 2. Multiply d(out)/d(b) with `backprop` due to chain rule, and then store the AVERAGED result in variable `db`
    # 3. Then, derive the gradient of weights, i.e., d(out)/d(w)
    # 4. Multiply d(out)/d(w) with `backprop` due to chain rule, and then store the AVERAGED result in variable `dw`
    # HINT: Shapes of `db` and `dw` should be (F,) and (D, F) respectively
    ####################
    # -----START OF YOUR CODE-----
    x, w, b, out = self.cache

    db = torch.sum(backprop,dim=0)/N # dim=0:縱向壓縮
    # print("db=",db)
    dw = torch.matmul(x.T,backprop)/N
    # print("dw=",dw)
    # ------END OF YOUR CODE------
    return dw, db

# %%
layer = FullyConnectedLayer()
FCL_Tests(layer)
# Out:
# Results of fully connected layer forward and backward tests: All passed.

# %% [markdown]
# ReLU (Rectified Linear Unit) is the currently most used non-linearity (or called activation function) in neural networks. Its formula as following:
# $$ReLU(t) = max(0, t)$$
#
# Since ReLU only allows positive values to be passed forward, any negative values of the input will not be able to propagate gradients during backpropagation.

# %%
class ReLU(object):
  def __init__(self):
    pass
  def forward(self, t):
    out = t.clone()
    ####################
    # TODO:
    # 1. Implement ReLU on `t` and store in variable `out`
    ####################
    # -----START OF YOUR CODE-----

    # x,y = out.shape
    # for i in range(x):
    #   for j in range(y):
    #     if out[i][j] < 0:
    #       out[i][j] = 0

    out[out<0]=0
    # ------END OF YOUR CODE------
    self.cache = (t, out)
    return out
  def backward(self, backprop):
    dt = torch.zeros_like(backprop)
    ####################
    # TODO:
    # 1. Derive d(out)/d(t)
    # 2. Multiply d(out)/d(t) with `backprop` due to chain rule, and then store the result in variable `dt`
    ####################
    # -----START OF YOUR CODE-----
    t,out = self.cache

    # for i in range(x):
    #   for j in range(y):
    #     if out[i][j] > 0:
    #       d_relu[i][j] = 1

    dt[out > 0] = 1 # out中元素>0的，d_relu中設成1
    # print("dt=",dt)
    # print("backprop",backprop)
    dt = dt * backprop # 每一項取and
    # print("new dt=",dt)

    # ------END OF YOUR CODE------
    return dt

# %%
layer = ReLU()
ReLU_Tests(layer)
# Out:
# Results of ReLU function tests: All passed.

# %% [markdown]
# Softmax is used to convert a vector of real numbers into a probability distribution over classes. It can be expressed mathematically as:
# $$softmax(\mathbf{S}_i)=\mathbf{p}_i=\frac{exp(\mathbf{S}_i)}{\sum_{j=1}^\mathbf{C}exp(\mathbf{S}_j)}$$
# And the cross-entropy loss, on the other hand, is a measure of the difference between the predicted probability distribution and the true probability distribution of the labels. Let $\mathbf{y}$ be **one-hot encoded** ground-truth label, that is, its shape would be the same with output of the network. Cross-entropy loss formula is defined as:
# $$CE = -\sum\mathbf{y}_i * log(\mathbf{p}_i)$$

# %%
class Softmax_CrossEntropy(object):
  def __init__(self):
    pass
  def forward(self, y, net_out):
    N, F = net_out.shape
    prob = torch.zeros_like(net_out)
    ####################
    # TODO:
    # 1. Implement Softmax and store the result in variable `prob`
    # HINT: Shape of `prob` should be (N, F)
    ####################
    # -----START OF YOUR CODE-----

    # print(torch.exp(net_out))
    # print("1:",torch.sum(torch.exp(net_out)))
    # print("2:",torch.sum(torch.exp(net_out),dim=1)) # 算完會轉成一列
    # print("3:",torch.sum(torch.exp(net_out),dim=1,keepdim=True))

    prob = torch.exp(net_out) / torch.sum(torch.exp(net_out),dim=1,keepdim=True)
    
    # ------END OF YOUR CODE------
    self.cache = (y, prob)
    pred_y = prob.argmax(dim=1)
    
    # 將標籤轉換為 one-hot 向量
    y_one_hot = torch.zeros_like(net_out)
    y_one_hot[np.arange(N), y] = 1

    loss = torch.zeros(1)
    ####################
    # TODO:
    # 1. Implement cross-entropy loss and store the result in variable `loss`
    ####################
    # -----START OF YOUR CODE-----
    # loss = -torch.sum(torch.log(prob)*pred_y + torch.log(torch.ones_like(prob)-prob)*(1-pred_y)) / N

    loss = -torch.sum(y_one_hot * torch.log(prob)) / N
    # ------END OF YOUR CODE------
    return pred_y, loss
  def backward(self):
    y, grad = self.cache
    N, F = grad.shape
    ####################
    # TODO:
    # 1. Derive the gradient of `net_out` and store the result in variable `grad`
    ####################
    # -----START OF YOUR CODE-----
    # grad_temp = grad
    grad[np.arange(N), y] -= 1
    grad = grad/N
    # grad=grad_temp
    # ------END OF YOUR CODE------
    return grad

# %%
# layer = Softmax_CrossEntropy()
# SCE_Tests(layer)

# %% [markdown]
# ## Network Definition

# %%
class Classifier(object):
  def __init__(self, dim_in, dim_hidden, dim_out, device='cpu'):
    self.dv = device
    np.random.seed(0)
    self.params = {'w1': torch.from_numpy(np.random.randn(dim_in, dim_hidden)*0.8).to(self.dv),
             'b1': torch.zeros(dim_hidden).to(self.dv),
             'w2': torch.from_numpy(np.random.randn(dim_hidden, dim_out)*0.8).to(self.dv),
             'b2': torch.zeros(dim_out).to(self.dv)}
    layer1 = FullyConnectedLayer()
    activation = ReLU()
    layer2 = FullyConnectedLayer()
    self.net = [layer1, activation, layer2]
    self.loss_func = Softmax_CrossEntropy()
  def save_model(self, path):
    torch.save(self.params, path)
  def load_model(self, path):
    checkpoint = torch.load(path, map_location=self.dv)
    self.params = checkpoint
  def training(self, train_dataloader, valid_dataloader, epochs=200, learning_rate=1e-3, learning_rate_decay=0.95, verbose=1):
    print(f'Training with batch_size={train_dataloader[0][0].shape[0]}, hidden_dim={self.params["w1"].shape[1]}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}')
    train_loss_log = []
    train_acc_log = []
    valid_loss_log = []
    valid_acc_log = []
    best_val_loss = None
    for epoch in range(epochs):
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(f'Epoch {epoch+1}:')
      single_epoch_log = ''
      train_loss = 0.0
      train_corr = 0.0; train_eval = 0.0
      for batch_idx in range(len(train_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = train_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
        pred_y, loss = self.loss_func.forward(batch_label, layer2_out)
        train_loss += loss.cpu().numpy()
        train_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        train_eval += batch_img.shape[0]
        ### Backpropagation and Optimization ###
        params_grad = {}
        dloss_dout2 = self.loss_func.backward()
        dout2_dw2, dout2_db2 = self.net[2].backward(dloss_dout2)
        params_grad['w2'] = dout2_dw2; params_grad['b2'] = dout2_db2
        dout2_dout1 = self.net[1].backward(dloss_dout2.mm(self.params['w2'].T))
        dout1_dw1, dout1_db1 = self.net[0].backward(dout2_dout1)
        params_grad['w1'] = dout1_dw1; params_grad['b1'] = dout1_db1
        ####################
        # TODO:
        # 1. Update model parameters, i.e., `self.params`, by gradient descent
        ####################
        # -----START OF YOUR CODE-----
        grads = {}
        for k, v in params_grad.items():
            grads[k] = v / batch_img.shape[0]
        self.params['w1'] -= learning_rate * grads['w1']
        self.params['b1'] -= learning_rate * grads['b1']
        self.params['w2'] -= learning_rate * grads['w2']
        self.params['b2'] -= learning_rate * grads['b2']        

        # ------END OF YOUR CODE------
      train_loss_log.append(train_loss/train_eval)
      train_acc_log.append(100*train_corr/train_eval)
      single_epoch_log += f'Training accuracy: {format(train_acc_log[-1], ".2f")}%, loss: {format(train_loss_log[-1], ".4f")}\n'
      train_dataloader.shuffle()

      valid_loss = 0.0
      valid_corr = 0.0; valid_eval = 0.0
      for batch_idx in range(len(valid_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = valid_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
        pred_y, loss = self.loss_func.forward(batch_label, layer2_out)
        valid_loss += loss.cpu().numpy()
        valid_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        valid_eval += batch_img.shape[0]
      valid_loss_log.append(valid_loss/valid_eval)
      valid_acc_log.append(100*valid_corr/valid_eval)
      single_epoch_log += f'Validaion accuracy: {format(valid_acc_log[-1], ".2f")}%, loss: {format(valid_loss_log[-1], ".4f")}'
      if best_val_loss is None or valid_loss < best_val_loss:
        best_val_loss = valid_loss
        self.save_model(MODEL_PATH)
        if verbose == 1:
          single_epoch_log = '[MODEL SAVED]\n' + single_epoch_log
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(single_epoch_log)
      learning_rate *= learning_rate_decay # update learning_rate every epoch
    return train_loss_log,train_acc_log,valid_loss_log,valid_acc_log
  def test(self, test_dataloader):
    total_corr = 0; total_eval = 0
    for batch_idx in range(len(test_dataloader)):
      ### Model Input ###
      batch_data = test_dataloader[batch_idx]
      batch_img, batch_label = batch_data
      layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
      layer1_out = self.net[1].forward(layer1_out)
      layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
      pred_y, _ = self.loss_func.forward(batch_label, layer2_out)
      total_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
      total_eval += batch_img.shape[0]
    print(f'Got {total_corr} correct prediction in {total_eval} test data, accuracy: {format((total_corr*1.0/total_eval)*100, ".2f")}%')

# %% [markdown]
# ## Searching for Best Hyperparameters
# Hyperparameters are configuration variables that set by users before model training. They influence the learning process and the final performance of the model. The goal of selecting optimal hyperparameters is to improve the model's accuracy and generalization ability.
#
# Hyperparameters in this assignment include hidden layer size, batch size, learning rate, and learning rate decay. You may change candidate values of them in the following cells and observe which might be useful to optimize the model. Howerver,  as running the whole section may take a while, you are allowed to not running all of the cells.

# %%
# Configurations
IN_DIM = np.prod(images[0].shape)
OUT_DIM = len(classes)

# %%
# Hyperparameters
BATCH_SIZE = 16
LR = 1e-3
LR_DECAY = 0.95
HIDEEN_DIM = 64

# %%
lr_cand = [1e-2, 1e-3, 1e-4]
train_acc = []
valid_acc = []

for lr in lr_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=lr, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(lr_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=64, learning_rate=0.01, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.0001, learning_rate_decay=0.95

# %%
bs_cand = [8, 16, 100]
train_acc = []
valid_acc = []

for bs in bs_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=bs)
  valid_dataloader = Dataloader(valid_dataset, batch_size=bs)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(bs_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=8, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=100, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95

# %%
hd_cand = [32, 64, 256]
train_acc = []
valid_acc = []

for hd in hd_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, hd, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(hd_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=32, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=256, learning_rate=0.001, learning_rate_decay=0.95

# %%
lr_decay_cand = [1.0, 0.95, 0.9]
train_acc = []
valid_acc = []

for lrd in lr_decay_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=lrd, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(lr_decay_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=1.0
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.9

# %% [markdown]
# ## Training with Best Hyperparameters

# %%
# Configurations
IN_DIM = np.prod(images[0].shape)
OUT_DIM = len(classes)

# %%
# Please set your hyperparameters here
BATCH_SIZE = 8 # 128
LR = 0.01 # 0.0001
LR_DECAY = 0.975
HIDEEN_DIM = 256

# %%
train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
train_loss, train_acc, valid_loss, valid_acc = model.training(train_dataloader, valid_dataloader, learning_rate=LR, learning_rate_decay=LR_DECAY)
plot_result(train_loss, train_acc, valid_loss, valid_acc)
# Out:
# Training with batch_size=8, hidden_dim=256, learning_rate=0.01, learning_rate_decay=0.975
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 19.86%, loss: nan
# Validaion accuracy: 18.13%, loss: 7.6831
# Epoch 2:
# [MODEL SAVED]
# Training accuracy: 27.62%, loss: 5.3925
# Validaion accuracy: 21.53%, loss: 6.1843
# Epoch 3:
# [MODEL SAVED]
# Training accuracy: 28.38%, loss: 4.6605
# Validaion accuracy: 23.30%, loss: 5.3862
# Epoch 4:
# [MODEL SAVED]
# Training accuracy: 29.63%, loss: 4.0949
# Validaion accuracy: 21.93%, loss: 5.2497
# Epoch 5:
# [MODEL SAVED]
# Training accuracy: 30.25%, loss: 3.6608
# Validaion accuracy: 23.74%, loss: 4.5596
# Epoch 6:
# [MODEL SAVED]
# Training accuracy: 31.46%, loss: 3.2041
# Validaion accuracy: 23.37%, loss: 4.3946
# Epoch 7:
# [MODEL SAVED]
# Training accuracy: 29.99%, loss: 3.1794
# Validaion accuracy: 24.55%, loss: 3.7942
# Epoch 8:
# [MODEL SAVED]
# Training accuracy: 31.53%, loss: 2.9199
# Validaion accuracy: 24.01%, loss: 3.5703
# Epoch 9:
# Training accuracy: 32.56%, loss: 2.5648
# Validaion accuracy: 24.34%, loss: 3.6043
# Epoch 10:
# [MODEL SAVED]
# Training accuracy: 32.60%, loss: 2.4949
# Validaion accuracy: 23.56%, loss: 3.4729
# Epoch 11:
# [MODEL SAVED]
# Training accuracy: 32.37%, loss: 2.3241
# Validaion accuracy: 22.22%, loss: 3.4297
# Epoch 12:
# [MODEL SAVED]
# Training accuracy: 33.76%, loss: 2.1922
# Validaion accuracy: 24.70%, loss: 2.7862
# Epoch 13:
# [MODEL SAVED]
# Training accuracy: 33.28%, loss: 2.1286
# Validaion accuracy: 26.73%, loss: 2.6769
# Epoch 14:
# [MODEL SAVED]
# Training accuracy: 32.85%, loss: 2.0047
# Validaion accuracy: 26.43%, loss: 2.5550
# Epoch 15:
# [MODEL SAVED]
# Training accuracy: 32.41%, loss: 1.9107
# Validaion accuracy: 25.59%, loss: 2.4952
# Epoch 16:
# [MODEL SAVED]
# Training accuracy: 33.26%, loss: 1.8422
# Validaion accuracy: 26.19%, loss: 2.3597
# Epoch 17:
# [MODEL SAVED]
# Training accuracy: 32.89%, loss: 1.7447
# Validaion accuracy: 26.25%, loss: 2.1681
# Epoch 18:
# [MODEL SAVED]
# Training accuracy: 34.10%, loss: 1.6282
# Validaion accuracy: 26.23%, loss: 2.1301
# Epoch 19:
# [MODEL SAVED]
# Training accuracy: 34.97%, loss: 1.5474
# Validaion accuracy: 26.28%, loss: 2.0960
# Epoch 20:
# [MODEL SAVED]
# Training accuracy: 33.90%, loss: 1.4936
# Validaion accuracy: 25.23%, loss: 1.9581
# Epoch 21:
# Training accuracy: 34.41%, loss: 1.3989
# Validaion accuracy: 25.08%, loss: 1.9904
# Epoch 22:
# [MODEL SAVED]
# Training accuracy: 34.16%, loss: 1.3763
# Validaion accuracy: 26.36%, loss: 1.7505
# Epoch 23:
# Training accuracy: 32.36%, loss: 1.3425
# Validaion accuracy: 25.37%, loss: 1.7550
# Epoch 24:
# [MODEL SAVED]
# Training accuracy: 33.84%, loss: 1.2610
# Validaion accuracy: 26.04%, loss: 1.6339
# Epoch 25:
# [MODEL SAVED]
# Training accuracy: 33.48%, loss: 1.2387
# Validaion accuracy: 27.00%, loss: 1.5337
# Epoch 26:
# [MODEL SAVED]
# Training accuracy: 33.73%, loss: 1.1902
# Validaion accuracy: 27.41%, loss: 1.5063
# Epoch 27:
# [MODEL SAVED]
# Training accuracy: 34.66%, loss: 1.1201
# Validaion accuracy: 26.03%, loss: 1.4632
# Epoch 28:
# [MODEL SAVED]
# Training accuracy: 32.85%, loss: 1.1311
# Validaion accuracy: 26.76%, loss: 1.3740
# Epoch 29:
# Training accuracy: 33.63%, loss: 1.0351
# Validaion accuracy: 25.85%, loss: 1.3987
# Epoch 30:
# Training accuracy: 35.87%, loss: 0.9967
# Validaion accuracy: 27.41%, loss: 1.3802
# Epoch 31:
# [MODEL SAVED]
# Training accuracy: 33.17%, loss: 0.9914
# Validaion accuracy: 26.04%, loss: 1.2921
# Epoch 32:
# [MODEL SAVED]
# Training accuracy: 33.80%, loss: 0.9823
# Validaion accuracy: 25.92%, loss: 1.2498
# Epoch 33:
# [MODEL SAVED]
# Training accuracy: 34.19%, loss: 0.9508
# Validaion accuracy: 24.16%, loss: 1.2086
# Epoch 34:
# Training accuracy: 34.41%, loss: 0.8832
# Validaion accuracy: 24.60%, loss: 1.2350
# Epoch 35:
# [MODEL SAVED]
# Training accuracy: 34.08%, loss: 0.8628
# Validaion accuracy: 27.16%, loss: 1.1129
# Epoch 36:
# [MODEL SAVED]
# Training accuracy: 33.61%, loss: 0.8444
# Validaion accuracy: 28.30%, loss: 1.0165
# Epoch 37:
# [MODEL SAVED]
# Training accuracy: 36.07%, loss: 0.7768
# Validaion accuracy: 27.16%, loss: 1.0135
# Epoch 38:
# Training accuracy: 35.71%, loss: 0.7644
# Validaion accuracy: 26.05%, loss: 1.1018
# Epoch 39:
# Training accuracy: 35.30%, loss: 0.7634
# Validaion accuracy: 25.57%, loss: 1.0392
# Epoch 40:
# [MODEL SAVED]
# Training accuracy: 35.65%, loss: 0.7288
# Validaion accuracy: 27.22%, loss: 0.9357
# Epoch 41:
# [MODEL SAVED]
# Training accuracy: 35.46%, loss: 0.6879
# Validaion accuracy: 26.82%, loss: 0.9298
# Epoch 42:
# [MODEL SAVED]
# Training accuracy: 35.14%, loss: 0.7043
# Validaion accuracy: 26.44%, loss: 0.8930
# Epoch 43:
# Training accuracy: 35.85%, loss: 0.6864
# Validaion accuracy: 24.66%, loss: 0.9266
# Epoch 44:
# [MODEL SAVED]
# Training accuracy: 35.59%, loss: 0.6428
# Validaion accuracy: 25.30%, loss: 0.8624
# Epoch 45:
# [MODEL SAVED]
# Training accuracy: 35.01%, loss: 0.6475
# Validaion accuracy: 26.26%, loss: 0.8571
# Epoch 46:
# Training accuracy: 35.35%, loss: 0.6340
# Validaion accuracy: 25.80%, loss: 0.8614
# Epoch 47:
# [MODEL SAVED]
# Training accuracy: 35.93%, loss: 0.5862
# Validaion accuracy: 26.05%, loss: 0.8502
# Epoch 48:
# [MODEL SAVED]
# Training accuracy: 34.92%, loss: 0.6029
# Validaion accuracy: 25.72%, loss: 0.7765
# Epoch 49:
# Training accuracy: 36.31%, loss: 0.5762
# Validaion accuracy: 26.51%, loss: 0.7864
# Epoch 50:
# [MODEL SAVED]
# Training accuracy: 34.88%, loss: 0.5690
# Validaion accuracy: 26.38%, loss: 0.7535
# Epoch 51:
# [MODEL SAVED]
# Training accuracy: 34.93%, loss: 0.5590
# Validaion accuracy: 26.76%, loss: 0.7228
# Epoch 52:
# [MODEL SAVED]
# Training accuracy: 35.39%, loss: 0.5668
# Validaion accuracy: 28.25%, loss: 0.6767
# Epoch 53:
# Training accuracy: 35.60%, loss: 0.5267
# Validaion accuracy: 26.01%, loss: 0.7308
# Epoch 54:
# [MODEL SAVED]
# Training accuracy: 35.40%, loss: 0.5352
# Validaion accuracy: 26.98%, loss: 0.6509
# Epoch 55:
# Training accuracy: 37.03%, loss: 0.5003
# Validaion accuracy: 25.38%, loss: 0.6759
# Epoch 56:
# [MODEL SAVED]
# Training accuracy: 36.78%, loss: 0.4923
# Validaion accuracy: 25.94%, loss: 0.6449
# Epoch 57:
# Training accuracy: 35.55%, loss: 0.5035
# Validaion accuracy: 27.28%, loss: 0.6597
# Epoch 58:
# [MODEL SAVED]
# Training accuracy: 34.85%, loss: 0.4847
# Validaion accuracy: 26.53%, loss: 0.6342
# Epoch 59:
# [MODEL SAVED]
# Training accuracy: 34.93%, loss: 0.4846
# Validaion accuracy: 28.41%, loss: 0.6037
# Epoch 60:
# [MODEL SAVED]
# Training accuracy: 35.21%, loss: 0.4666
# Validaion accuracy: 26.29%, loss: 0.5999
# Epoch 61:
# Training accuracy: 35.52%, loss: 0.4627
# Validaion accuracy: 26.66%, loss: 0.6202
# Epoch 62:
# Training accuracy: 37.09%, loss: 0.4510
# Validaion accuracy: 26.77%, loss: 0.6139
# Epoch 63:
# [MODEL SAVED]
# Training accuracy: 36.83%, loss: 0.4599
# Validaion accuracy: 26.09%, loss: 0.5658
# Epoch 64:
# [MODEL SAVED]
# Training accuracy: 36.13%, loss: 0.4391
# Validaion accuracy: 27.38%, loss: 0.5382
# Epoch 65:
# Training accuracy: 35.36%, loss: 0.4335
# Validaion accuracy: 27.29%, loss: 0.5679
# Epoch 66:
# Training accuracy: 35.58%, loss: 0.4366
# Validaion accuracy: 26.76%, loss: 0.5679
# Epoch 67:
# Training accuracy: 35.75%, loss: 0.4201
# Validaion accuracy: 26.02%, loss: 0.5412
# Epoch 68:
# [MODEL SAVED]
# Training accuracy: 36.76%, loss: 0.4135
# Validaion accuracy: 27.56%, loss: 0.5235
# Epoch 69:
# Training accuracy: 35.03%, loss: 0.4103
# Validaion accuracy: 27.87%, loss: 0.5276
# Epoch 70:
# [MODEL SAVED]
# Training accuracy: 36.82%, loss: 0.4034
# Validaion accuracy: 27.81%, loss: 0.5105
# Epoch 71:
# Training accuracy: 35.93%, loss: 0.4030
# Validaion accuracy: 26.18%, loss: 0.5168
# Epoch 72:
# [MODEL SAVED]
# Training accuracy: 35.10%, loss: 0.4116
# Validaion accuracy: 27.08%, loss: 0.4927
# Epoch 73:
# Training accuracy: 36.54%, loss: 0.4028
# Validaion accuracy: 27.49%, loss: 0.4983
# Epoch 74:
# Training accuracy: 36.17%, loss: 0.4059
# Validaion accuracy: 25.97%, loss: 0.5094
# Epoch 75:
# [MODEL SAVED]
# Training accuracy: 36.42%, loss: 0.3899
# Validaion accuracy: 28.45%, loss: 0.4802
# Epoch 76:
# [MODEL SAVED]
# Training accuracy: 36.58%, loss: 0.3950
# Validaion accuracy: 28.11%, loss: 0.4615
# Epoch 77:
# Training accuracy: 35.60%, loss: 0.3800
# Validaion accuracy: 27.82%, loss: 0.4729
# Epoch 78:
# Training accuracy: 36.13%, loss: 0.3962
# Validaion accuracy: 26.90%, loss: 0.4693
# Epoch 79:
# Training accuracy: 36.26%, loss: 0.3758
# Validaion accuracy: 24.77%, loss: 0.4757
# Epoch 80:
# [MODEL SAVED]
# Training accuracy: 36.87%, loss: 0.3802
# Validaion accuracy: 26.42%, loss: 0.4483
# Epoch 81:
# Training accuracy: 34.48%, loss: 0.3899
# Validaion accuracy: 26.94%, loss: 0.4567
# Epoch 82:
# [MODEL SAVED]
# Training accuracy: 35.92%, loss: 0.3699
# Validaion accuracy: 28.59%, loss: 0.4290
# Epoch 83:
# Training accuracy: 35.98%, loss: 0.3690
# Validaion accuracy: 28.91%, loss: 0.4357
# Epoch 84:
# [MODEL SAVED]
# Training accuracy: 35.68%, loss: 0.3761
# Validaion accuracy: 28.19%, loss: 0.4279
# Epoch 85:
# Training accuracy: 35.98%, loss: 0.3574
# Validaion accuracy: 28.47%, loss: 0.4481
# Epoch 86:
# Training accuracy: 35.49%, loss: 0.3553
# Validaion accuracy: 25.82%, loss: 0.4517
# Epoch 87:
# Training accuracy: 35.83%, loss: 0.3635
# Validaion accuracy: 27.71%, loss: 0.4524
# Epoch 88:
# [MODEL SAVED]
# Training accuracy: 34.92%, loss: 0.3629
# Validaion accuracy: 27.56%, loss: 0.4187
# Epoch 89:
# Training accuracy: 36.31%, loss: 0.3540
# Validaion accuracy: 28.03%, loss: 0.4324
# Epoch 90:
# Training accuracy: 35.96%, loss: 0.3531
# Validaion accuracy: 25.70%, loss: 0.4267
# Epoch 91:
# Training accuracy: 36.59%, loss: 0.3423
# Validaion accuracy: 27.46%, loss: 0.4224
# Epoch 92:
# Training accuracy: 35.47%, loss: 0.3607
# Validaion accuracy: 29.15%, loss: 0.4230
# Epoch 93:
# [MODEL SAVED]
# Training accuracy: 37.19%, loss: 0.3424
# Validaion accuracy: 30.77%, loss: 0.3957
# Epoch 94:
# Training accuracy: 35.80%, loss: 0.3599
# Validaion accuracy: 27.88%, loss: 0.4100
# Epoch 95:
# Training accuracy: 35.40%, loss: 0.3469
# Validaion accuracy: 27.38%, loss: 0.3996
# Epoch 96:
# Training accuracy: 34.76%, loss: 0.3334
# Validaion accuracy: 29.14%, loss: 0.3990
# Epoch 97:
# Training accuracy: 35.55%, loss: 0.3564
# Validaion accuracy: 28.51%, loss: 0.3978
# Epoch 98:
# Training accuracy: 35.78%, loss: 0.3358
# Validaion accuracy: 29.97%, loss: 0.3981
# Epoch 99:
# Training accuracy: 35.48%, loss: 0.3529
# Validaion accuracy: 27.62%, loss: 0.4087
# Epoch 100:
# Training accuracy: 36.46%, loss: 0.3481
# Validaion accuracy: 26.38%, loss: 0.4023
# Epoch 101:
# [MODEL SAVED]
# Training accuracy: 35.45%, loss: 0.3476
# Validaion accuracy: 29.00%, loss: 0.3896
# Epoch 102:
# [MODEL SAVED]
# Training accuracy: 35.45%, loss: 0.3421
# Validaion accuracy: 29.71%, loss: 0.3846
# Epoch 103:
# Training accuracy: 36.74%, loss: 0.3306
# Validaion accuracy: 29.47%, loss: 0.3901
# Epoch 104:
# Training accuracy: 36.23%, loss: 0.3315
# Validaion accuracy: 28.62%, loss: 0.3850
# Epoch 105:
# [MODEL SAVED]
# Training accuracy: 36.44%, loss: 0.3335
# Validaion accuracy: 29.38%, loss: 0.3808
# Epoch 106:
# Training accuracy: 35.83%, loss: 0.3322
# Validaion accuracy: 30.06%, loss: 0.3860
# Epoch 107:
# Training accuracy: 35.65%, loss: 0.3350
# Validaion accuracy: 26.93%, loss: 0.3955
# Epoch 108:
# Training accuracy: 35.92%, loss: 0.3353
# Validaion accuracy: 28.59%, loss: 0.3849
# Epoch 109:
# [MODEL SAVED]
# Training accuracy: 34.82%, loss: 0.3295
# Validaion accuracy: 28.28%, loss: 0.3763
# Epoch 110:
# Training accuracy: 35.14%, loss: 0.3338
# Validaion accuracy: 29.57%, loss: 0.3810
# Epoch 111:
# [MODEL SAVED]
# Training accuracy: 35.13%, loss: 0.3353
# Validaion accuracy: 29.79%, loss: 0.3717
# Epoch 112:
# Training accuracy: 34.49%, loss: 0.3418
# Validaion accuracy: 27.30%, loss: 0.3926
# Epoch 113:
# Training accuracy: 33.90%, loss: 0.3437
# Validaion accuracy: 29.78%, loss: 0.3823
# Epoch 114:
# Training accuracy: 35.83%, loss: 0.3213
# Validaion accuracy: 28.67%, loss: 0.3734
# Epoch 115:
# Training accuracy: 36.02%, loss: 0.3360
# Validaion accuracy: 28.29%, loss: 0.3747
# Epoch 116:
# [MODEL SAVED]
# Training accuracy: 35.18%, loss: 0.3247
# Validaion accuracy: 29.55%, loss: 0.3707
# Epoch 117:
# [MODEL SAVED]
# Training accuracy: 34.73%, loss: 0.3372
# Validaion accuracy: 30.58%, loss: 0.3668
# Epoch 118:
# [MODEL SAVED]
# Training accuracy: 36.28%, loss: 0.3247
# Validaion accuracy: 29.30%, loss: 0.3650
# Epoch 119:
# Training accuracy: 35.49%, loss: 0.3222
# Validaion accuracy: 29.98%, loss: 0.3744
# Epoch 120:
# [MODEL SAVED]
# Training accuracy: 35.46%, loss: 0.3177
# Validaion accuracy: 30.35%, loss: 0.3627
# Epoch 121:
# Training accuracy: 35.60%, loss: 0.3336
# Validaion accuracy: 29.54%, loss: 0.3660
# Epoch 122:
# Training accuracy: 35.41%, loss: 0.3261
# Validaion accuracy: 26.80%, loss: 0.3796
# Epoch 123:
# Training accuracy: 35.61%, loss: 0.3215
# Validaion accuracy: 30.12%, loss: 0.3798
# Epoch 124:
# Training accuracy: 34.47%, loss: 0.3207
# Validaion accuracy: 28.02%, loss: 0.3745
# Epoch 125:
# [MODEL SAVED]
# Training accuracy: 35.04%, loss: 0.3310
# Validaion accuracy: 29.33%, loss: 0.3604
# Epoch 126:
# Training accuracy: 34.07%, loss: 0.3325
# Validaion accuracy: 29.15%, loss: 0.3629
# Epoch 127:
# Training accuracy: 36.17%, loss: 0.3123
# Validaion accuracy: 29.55%, loss: 0.3631
# Epoch 128:
# [MODEL SAVED]
# Training accuracy: 36.02%, loss: 0.3193
# Validaion accuracy: 30.51%, loss: 0.3572
# Epoch 129:
# Training accuracy: 34.54%, loss: 0.3332
# Validaion accuracy: 30.61%, loss: 0.3575
# Epoch 130:
# Training accuracy: 34.94%, loss: 0.3213
# Validaion accuracy: 28.67%, loss: 0.3650
# Epoch 131:
# [MODEL SAVED]
# Training accuracy: 35.32%, loss: 0.3282
# Validaion accuracy: 30.43%, loss: 0.3533
# Epoch 132:
# Training accuracy: 35.86%, loss: 0.3307
# Validaion accuracy: 29.82%, loss: 0.3562
# Epoch 133:
# Training accuracy: 34.60%, loss: 0.3300
# Validaion accuracy: 27.06%, loss: 0.3734
# Epoch 134:
# Training accuracy: 34.84%, loss: 0.3245
# Validaion accuracy: 29.50%, loss: 0.3575
# Epoch 135:
# Training accuracy: 33.39%, loss: 0.3255
# Validaion accuracy: 28.43%, loss: 0.3555
# Epoch 136:
# [MODEL SAVED]
# Training accuracy: 34.39%, loss: 0.3241
# Validaion accuracy: 30.51%, loss: 0.3512
# Epoch 137:
# Training accuracy: 34.58%, loss: 0.3122
# Validaion accuracy: 30.44%, loss: 0.3545
# Epoch 138:
# Training accuracy: 34.99%, loss: 0.3047
# Validaion accuracy: 30.99%, loss: 0.3518
# Epoch 139:
# Training accuracy: 35.97%, loss: 0.3135
# Validaion accuracy: 31.95%, loss: 0.3529
# Epoch 140:
# Training accuracy: 34.22%, loss: 0.3209
# Validaion accuracy: 31.39%, loss: 0.3522
# Epoch 141:
# [MODEL SAVED]
# Training accuracy: 34.78%, loss: 0.3166
# Validaion accuracy: 31.71%, loss: 0.3508
# Epoch 142:
# [MODEL SAVED]
# Training accuracy: 35.08%, loss: 0.3163
# Validaion accuracy: 30.51%, loss: 0.3507
# Epoch 143:
# Training accuracy: 35.00%, loss: 0.3217
# Validaion accuracy: 30.46%, loss: 0.3553
# Epoch 144:
# Training accuracy: 34.13%, loss: 0.3356
# Validaion accuracy: 31.47%, loss: 0.3528
# Epoch 145:
# Training accuracy: 35.05%, loss: 0.3163
# Validaion accuracy: 29.87%, loss: 0.3536
# Epoch 146:
# Training accuracy: 35.55%, loss: 0.3118
# Validaion accuracy: 30.11%, loss: 0.3516
# Epoch 147:
# Training accuracy: 35.02%, loss: 0.3264
# Validaion accuracy: 29.38%, loss: 0.3532
# Epoch 148:
# [MODEL SAVED]
# Training accuracy: 34.68%, loss: 0.3230
# Validaion accuracy: 30.27%, loss: 0.3490
# Epoch 149:
# Training accuracy: 34.48%, loss: 0.3397
# Validaion accuracy: 29.46%, loss: 0.3530
# Epoch 150:
# Training accuracy: 35.67%, loss: 0.3206
# Validaion accuracy: 30.53%, loss: 0.3502
# Epoch 151:
# Training accuracy: 33.99%, loss: 0.3280
# Validaion accuracy: 31.55%, loss: 0.3492
# Epoch 152:
# Training accuracy: 34.27%, loss: 0.3412
# Validaion accuracy: 30.61%, loss: 0.3499
# Epoch 153:
# Training accuracy: 34.68%, loss: 0.3261
# Validaion accuracy: 30.82%, loss: 0.3499
# Epoch 154:
# Training accuracy: 35.49%, loss: 0.3187
# Validaion accuracy: 30.43%, loss: 0.3513
# Epoch 155:
# Training accuracy: 34.80%, loss: 0.3185
# Validaion accuracy: 29.95%, loss: 0.3521
# Epoch 156:
# Training accuracy: 34.96%, loss: 0.3197
# Validaion accuracy: 30.11%, loss: 0.3491
# Epoch 157:
# [MODEL SAVED]
# Training accuracy: 33.85%, loss: 0.3369
# Validaion accuracy: 31.55%, loss: 0.3468
# Epoch 158:
# Training accuracy: 34.07%, loss: 0.3239
# Validaion accuracy: 30.67%, loss: 0.3471
# Epoch 159:
# Training accuracy: 34.57%, loss: 0.3244
# Validaion accuracy: 30.83%, loss: 0.3514
# Epoch 160:
# [MODEL SAVED]
# Training accuracy: 35.13%, loss: 0.3353
# Validaion accuracy: 31.47%, loss: 0.3450
# Epoch 161:
# Training accuracy: 34.31%, loss: 0.3176
# Validaion accuracy: 31.90%, loss: 0.3465
# Epoch 162:
# Training accuracy: 34.99%, loss: 0.3172
# Validaion accuracy: 30.75%, loss: 0.3456
# Epoch 163:
# Training accuracy: 34.33%, loss: 0.3191
# Validaion accuracy: 30.43%, loss: 0.3471
# Epoch 164:
# [MODEL SAVED]
# Training accuracy: 34.41%, loss: 0.3177
# Validaion accuracy: 31.09%, loss: 0.3448
# Epoch 165:
# [MODEL SAVED]
# Training accuracy: 35.46%, loss: 0.3163
# Validaion accuracy: 32.03%, loss: 0.3428
# Epoch 166:
# Training accuracy: 33.59%, loss: 0.3129
# Validaion accuracy: 30.59%, loss: 0.3471
# Epoch 167:
# Training accuracy: 33.05%, loss: 0.3165
# Validaion accuracy: 31.25%, loss: 0.3442
# Epoch 168:
# Training accuracy: 35.31%, loss: 0.3087
# Validaion accuracy: 30.43%, loss: 0.3433
# Epoch 169:
# Training accuracy: 33.65%, loss: 0.3215
# Validaion accuracy: 29.14%, loss: 0.3490
# Epoch 170:
# [MODEL SAVED]
# Training accuracy: 34.26%, loss: 0.3333
# Validaion accuracy: 31.39%, loss: 0.3419
# Epoch 171:
# Training accuracy: 34.31%, loss: 0.3284
# Validaion accuracy: 30.67%, loss: 0.3444
# Epoch 172:
# Training accuracy: 35.57%, loss: 0.3178
# Validaion accuracy: 31.79%, loss: 0.3432
# Epoch 173:
# [MODEL SAVED]
# Training accuracy: 33.64%, loss: 0.3231
# Validaion accuracy: 31.39%, loss: 0.3406
# Epoch 174:
# Training accuracy: 34.06%, loss: 0.3176
# Validaion accuracy: 30.51%, loss: 0.3456
# Epoch 175:
# Training accuracy: 35.57%, loss: 0.3139
# Validaion accuracy: 31.31%, loss: 0.3432
# Epoch 176:
# Training accuracy: 35.68%, loss: 0.3040
# Validaion accuracy: 31.07%, loss: 0.3424
# Epoch 177:
# Training accuracy: 33.48%, loss: 0.3224
# Validaion accuracy: 31.71%, loss: 0.3416
# Epoch 178:
# Training accuracy: 35.73%, loss: 0.3184
# Validaion accuracy: 32.19%, loss: 0.3410
# Epoch 179:
# Training accuracy: 35.72%, loss: 0.3188
# Validaion accuracy: 29.74%, loss: 0.3456
# Epoch 180:
# Training accuracy: 33.80%, loss: 0.3277
# Validaion accuracy: 32.27%, loss: 0.3421
# Epoch 181:
# [MODEL SAVED]
# Training accuracy: 33.28%, loss: 0.3285
# Validaion accuracy: 31.97%, loss: 0.3403
# Epoch 182:
# [MODEL SAVED]
# Training accuracy: 33.91%, loss: 0.3303
# Validaion accuracy: 31.87%, loss: 0.3402
# Epoch 183:
# Training accuracy: 34.26%, loss: 0.3126
# Validaion accuracy: 31.47%, loss: 0.3413
# Epoch 184:
# Training accuracy: 34.35%, loss: 0.3281
# Validaion accuracy: 29.63%, loss: 0.3422
# Epoch 185:
# Training accuracy: 33.59%, loss: 0.3233
# Validaion accuracy: 30.91%, loss: 0.3403
# Epoch 186:
# Training accuracy: 34.00%, loss: 0.3150
# Validaion accuracy: 30.91%, loss: 0.3408
# Epoch 187:
# Training accuracy: 34.39%, loss: 0.3247
# Validaion accuracy: 31.31%, loss: 0.3415
# Epoch 188:
# [MODEL SAVED]
# Training accuracy: 33.68%, loss: 0.3232
# Validaion accuracy: 31.87%, loss: 0.3393
# Epoch 189:
# [MODEL SAVED]
# Training accuracy: 34.13%, loss: 0.3174
# Validaion accuracy: 31.23%, loss: 0.3390
# Epoch 190:
# Training accuracy: 33.79%, loss: 0.3222
# Validaion accuracy: 30.59%, loss: 0.3422
# Epoch 191:
# Training accuracy: 33.80%, loss: 0.3175
# Validaion accuracy: 31.95%, loss: 0.3396
# Epoch 192:
# Training accuracy: 33.59%, loss: 0.3205
# Validaion accuracy: 32.19%, loss: 0.3401
# Epoch 193:
# Training accuracy: 34.39%, loss: 0.3158
# Validaion accuracy: 31.15%, loss: 0.3393
# Epoch 194:
# [MODEL SAVED]
# Training accuracy: 34.98%, loss: 0.3076
# Validaion accuracy: 31.39%, loss: 0.3386
# Epoch 195:
# Training accuracy: 34.32%, loss: 0.3158
# Validaion accuracy: 30.43%, loss: 0.3421
# Epoch 196:
# Training accuracy: 33.29%, loss: 0.3224
# Validaion accuracy: 30.51%, loss: 0.3422
# Epoch 197:
# Training accuracy: 33.78%, loss: 0.3154
# Validaion accuracy: 31.55%, loss: 0.3392
# Epoch 198:
# Training accuracy: 33.40%, loss: 0.3158
# Validaion accuracy: 32.19%, loss: 0.3390
# Epoch 199:
# Training accuracy: 33.03%, loss: 0.3261
# Validaion accuracy: 31.23%, loss: 0.3416
# Epoch 200:
# Training accuracy: 33.34%, loss: 0.3245
# Validaion accuracy: 32.11%, loss: 0.3391

# %% [markdown]
# Test the model with test_dataset. <font color='red'>The test accuracy must reach at least 28%.</font>

# %%
test_dataloader = Dataloader(test_dataset)
model.load_model(MODEL_PATH)
model.test(test_dataloader)
# Out:
# Got 3222 correct prediction in 10000 test data, accuracy: 32.22%
